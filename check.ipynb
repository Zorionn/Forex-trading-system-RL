# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
DF_EUR_USD = pd.read_csv("EUR_USD_2010_2017_bid_ask.csv")

# %%
DF_EUR_USD['Time'] = pd.to_datetime(DF_EUR_USD['Time'])

# %%
DF_EUR_USD
# Out:
#                           Time  Bid_Open  Bid_Close  Ask_Open  Ask_Close
# 0    2009-12-31 22:00:00+00:00   1.43070    1.43070   1.43170    1.43170
# 1    2010-01-02 22:00:00+00:00   1.43070    1.43016   1.43170    1.43056
# 2    2010-01-03 22:00:00+00:00   1.43010    1.44118   1.43050    1.44136
# 3    2010-01-04 22:00:00+00:00   1.44114    1.43640   1.44132    1.43660
# 4    2010-01-05 22:00:00+00:00   1.43655    1.44069   1.43675    1.44087
# ...                        ...       ...        ...       ...        ...
# 2362 2017-12-21 22:00:00+00:00   1.18726    1.18587   1.18786    1.18647
# 2363 2017-12-25 22:00:00+00:00   1.18658    1.18558   1.18718    1.18610
# 2364 2017-12-26 22:00:00+00:00   1.18539    1.18851   1.18599    1.18911
# 2365 2017-12-27 22:00:00+00:00   1.18949    1.19418   1.19009    1.19478
# 2366 2017-12-28 22:00:00+00:00   1.19402    1.20009   1.19462    1.20069
#
# [2367 rows x 5 columns]

# %%
# DF_EUR_USD = DF_EUR_USD.head(1000)

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.set_xlabel('Time')
ax1.set_ylabel('Bid_Close', color='tab:blue')
ax1.plot(DF_EUR_USD['Time'], DF_EUR_USD['Bid_Close'], color='tab:blue', label='Bid_Close')
ax1.tick_params(axis='y', labelcolor='tab:blue')

ax2 = ax1.twinx()
ax2.set_ylabel('Ask_Close', color='tab:green')
ax2.plot(DF_EUR_USD['Time'], DF_EUR_USD['Ask_Close'], color='tab:green', linestyle='--', label='Ask_Close')
ax2.tick_params(axis='y', labelcolor='tab:green')

plt.title('Historical Data EUR/USD')
fig.tight_layout()  # To prevent overlapping labels
plt.show()
